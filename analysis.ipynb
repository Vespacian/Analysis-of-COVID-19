# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv("COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv").head(1500)
data
# Out:
# C:\Users\derek\AppData\Local\Temp\ipykernel_21852\1235390238.py:1: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv").head(1500)
#      hospital_pk collection_week state     ccn  \
# 0         052052      2020/05/29    CA  052052
# 1         070038      2020/04/24    CT  070038
# 2         100034      2020/05/01    FL  100034
# 3         100069      2020/05/15    FL  100069
# 4         100070      2020/04/24    FL  100070
# ...          ...             ...   ...     ...
# 1495      192013      2020/04/17    LA  192013
# 1496      192029      2020/04/03    LA  192029
# 1497      200009      2020/05/01    ME  200009
# 1498      200034      2020/05/08    ME  200034
# 1499      201315      2020/05/22    ME  201315
#
#                                           hospital_name  \
# 0                            KINDRED HOSPITAL RIVERSIDE
# 1                           CONNECTICUT HOSPICE INC,THE
# 2            MOUNT SINAI MEDICAL CENTER OF FLORIDA, INC
# 3                              ADVENTHEALTH CARROLLWOOD
# 4                              SHOREPOINT HEALTH VENICE
# ...                                                 ...
# 1495  CORNERSTONE SPECIALTY HOSPITALS SOUTHWEST LOUI...
# 1496               LAFAYETTE - A M G SPECIALTY HOSPITAL
# 1497                               MAINE MEDICAL CENTER
# 1498                  ST MARY'S REGIONAL MEDICAL CENTER
# 1499                         STEPHENS MEMORIAL HOSPITAL
#
#                                       address          city      zip  \
# 0                   2224 MEDICAL CENTER DRIVE        PERRIS  92571.0
# 1                       100 DOUBLE BEACH ROAD      BRANFORD   6405.0
# 2                               4300 ALTON RD   MIAMI BEACH  33140.0
# 3                       7171 N DALE MABRY HWY         TAMPA  33614.0
# 4                              540 THE RIALTO        VENICE  34285.0
# ...                                       ...           ...      ...
# 1495  524 DR MICHAEL DEBAKEY DRIVE, 3RD FLOOR  LAKE CHARLES  70601.0
# 1496  4811 AMBASSADOR CAFFERY PKWY, 4TH FLOOR     LAFAYETTE  70506.0
# 1497                           22 BRAMHALL ST      PORTLAND   4102.0
# 1498            93 CAMPUS AVENUE - PO BOX 291      LEWISTON   4243.0
# 1499                          181 MAIN STREET        NORWAY   4268.0
#
#                hospital_subtype  fips_code  ...  \
# 0                     Long Term     6065.0  ...
# 1                    Short Term     9009.0  ...
# 2                    Short Term    12086.0  ...
# 3                    Short Term    12057.0  ...
# 4                    Short Term    12115.0  ...
# ...                         ...        ...  ...
# 1495                  Long Term    22019.0  ...
# 1496                  Long Term    22055.0  ...
# 1497                 Short Term    23005.0  ...
# 1498                 Short Term    23001.0  ...
# 1499  Critical Access Hospitals    23017.0  ...
#
#       previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1495                                                NaN
# 1496                                                NaN
# 1497                                                NaN
# 1498                                                NaN
# 1499                                                NaN
#
#       staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1495                                                NaN
# 1496                                                NaN
# 1497                                                NaN
# 1498                                                NaN
# 1499                                                NaN
#
#       staffed_icu_pediatric_patients_confirmed_covid_7_day_coverage  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1495                                                  0
# 1496                                                  0
# 1497                                                  0
# 1498                                                  0
# 1499                                                  0
#
#       staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1495                                                NaN
# 1496                                                NaN
# 1497                                                NaN
# 1498                                                NaN
# 1499                                                NaN
#
#       staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 1495                                            NaN
# 1496                                            NaN
# 1497                                            NaN
# 1498                                            NaN
# 1499                                            NaN
#
#       staffed_pediatric_icu_bed_occupancy_7_day_coverage  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1495                                                  0
# 1496                                                  0
# 1497                                                  0
# 1498                                                  0
# 1499                                                  0
#
#       staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 1495                                            NaN
# 1496                                            NaN
# 1497                                            NaN
# 1498                                            NaN
# 1499                                            NaN
#
#       total_staffed_pediatric_icu_beds_7_day_avg  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1495                                         NaN
# 1496                                         NaN
# 1497                                         NaN
# 1498                                         NaN
# 1499                                         NaN
#
#       total_staffed_pediatric_icu_beds_7_day_coverage  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 1495                                                0
# 1496                                                0
# 1497                                                0
# 1498                                                0
# 1499                                                0
#
#       total_staffed_pediatric_icu_beds_7_day_sum
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1495                                         NaN
# 1496                                         NaN
# 1497                                         NaN
# 1498                                         NaN
# 1499                                         NaN
#
# [1500 rows x 128 columns]
