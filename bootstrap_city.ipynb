# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
data = pd.read_csv('COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv').head(800000).sort_values(['city'])
data.head()
# Out:
# /var/folders/0x/j2sfsgp167vf2w83dyjt6_nm0000gn/T/ipykernel_12174/2033632590.py:1: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv').head(800000).sort_values(['city'])
#        hospital_pk collection_week state     ccn  \
# 147552      190034      2021/02/12    LA  190034
# 577721      421301      2022/09/02    SC  421301
# 70132       421301      2022/12/30    SC  421301
# 571322      190034      2020/12/04    LA  190034
# 149854      190034      2023/01/27    LA  190034
#
#                         hospital_name             address       city      zip  \
# 147552     ABBEVILLE GENERAL HOSPITAL   118 N HOSPITAL DR  ABBEVILLE  70510.0
# 577721  ABBEVILLE AREA MEDICAL CENTER  420 THOMSON CIRCLE  ABBEVILLE  29620.0
# 70132   ABBEVILLE AREA MEDICAL CENTER  420 THOMSON CIRCLE  ABBEVILLE  29620.0
# 571322     ABBEVILLE GENERAL HOSPITAL   118 N HOSPITAL DR  ABBEVILLE  70510.0
# 149854     ABBEVILLE GENERAL HOSPITAL   118 N HOSPITAL DR  ABBEVILLE  70510.0
#
#                  hospital_subtype  fips_code  ...  \
# 147552                 Short Term    22113.0  ...
# 577721  Critical Access Hospitals    45001.0  ...
# 70132   Critical Access Hospitals    45001.0  ...
# 571322                 Short Term    22113.0  ...
# 149854                 Short Term    22113.0  ...
#
#         previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_coverage  \
# 147552                                                  0
# 577721                                                  7
# 70132                                                   7
# 571322                                                  0
# 149854                                                  7
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
#
#         staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# 147552                                            NaN
# 577721                                            0.0
# 70132                                             0.0
# 571322                                            NaN
# 149854                                            0.0
#
#         staffed_pediatric_icu_bed_occupancy_7_day_coverage  \
# 147552                                                  0
# 577721                                                  7
# 70132                                                   7
# 571322                                                  0
# 149854                                                  7
#
#         staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# 147552                                            NaN
# 577721                                            0.0
# 70132                                             0.0
# 571322                                            NaN
# 149854                                            0.0
#
#         total_staffed_pediatric_icu_beds_7_day_avg  \
# 147552                                         NaN
# 577721                                         0.0
# 70132                                          0.0
# 571322                                         NaN
# 149854                                         0.0
#
#         total_staffed_pediatric_icu_beds_7_day_coverage  \
# 147552                                                0
# 577721                                                7
# 70132                                                 7
# 571322                                                0
# 149854                                                7
#
#         total_staffed_pediatric_icu_beds_7_day_sum
# 147552                                         NaN
# 577721                                         0.0
# 70132                                          0.0
# 571322                                         NaN
# 149854                                         0.0
#
# [5 rows x 128 columns]

# %%
len(data)
# Out:
# 742253

# %%
def ifZero(x):
    if x < 0:
        return 0
    return x

# %%
clean = data
for col in clean.columns:
  if clean[col].dtype != 'float64':
    clean = clean.drop(col, axis=1)
clean = clean.drop(['zip', 'fips_code'], axis=1)
clean
# Out:
#         total_beds_7_day_avg  all_adult_hospital_beds_7_day_avg  \
# 147552                  42.4                               40.4
# 577721                   NaN                                NaN
# 70132                    NaN                                NaN
# 571322                  36.0                               34.0
# 149854                   NaN                                NaN
# ...                      ...                                ...
# 739122                 101.0                                NaN
# 739631                   NaN                                NaN
# 740480                  10.0                               10.0
# 741230                   NaN                                NaN
# 741620                   0.0                                0.0
#
#         all_adult_hospital_inpatient_beds_7_day_avg  \
# 147552                                         40.4
# 577721                                         18.0
# 70132                                          18.0
# 571322                                         34.0
# 149854                                         56.0
# ...                                             ...
# 739122                                          NaN
# 739631                                          0.0
# 740480                                         10.0
# 741230                                         10.0
# 741620                                          0.0
#
#         inpatient_beds_used_7_day_avg  \
# 147552                           18.7
# 577721                           11.4
# 70132                            13.0
# 571322                           20.7
# 149854                           27.9
# ...                               ...
# 739122                           19.1
# 739631                            0.0
# 740480                            8.0
# 741230                      -999999.0
# 741620                            0.0
#
#         all_adult_hospital_inpatient_bed_occupied_7_day_avg  \
# 147552                                               18.7
# 577721                                               11.4
# 70132                                                13.0
# 571322                                               20.7
# 149854                                               27.9
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                8.0
# 741230                                          -999999.0
# 741620                                                0.0
#
#         inpatient_beds_used_covid_7_day_avg  \
# 147552                            -999999.0
# 577721                                  0.0
# 70132                             -999999.0
# 571322                            -999999.0
# 149854                            -999999.0
# ...                                     ...
# 739122                                  0.0
# 739631                                  0.0
# 740480                                  0.0
# 741230                                  0.0
# 741620                                  NaN
#
#         total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg  \
# 147552                                          -999999.0
# 577721                                                0.0
# 70132                                           -999999.0
# 571322                                          -999999.0
# 149854                                          -999999.0
# ...                                                   ...
# 739122                                                0.0
# 739631                                                0.0
# 740480                                                0.0
# 741230                                                0.0
# 741620                                                NaN
#
#         total_adult_patients_hospitalized_confirmed_covid_7_day_avg  \
# 147552                                          -999999.0
# 577721                                                0.0
# 70132                                           -999999.0
# 571322                                          -999999.0
# 149854                                          -999999.0
# ...                                                   ...
# 739122                                                0.0
# 739631                                                0.0
# 740480                                                0.0
# 741230                                                0.0
# 741620                                                NaN
#
#         total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg  \
# 147552                                                0.0
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                0.0
# 149854                                                0.0
# ...                                                   ...
# 739122                                                0.0
# 739631                                                0.0
# 740480                                                0.0
# 741230                                                0.0
# 741620                                                NaN
#
#         total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg  ...  \
# 147552                                                0.0                ...
# 577721                                                0.0                ...
# 70132                                                 0.0                ...
# 571322                                                0.0                ...
# 149854                                                0.0                ...
# ...                                                   ...                ...
# 739122                                                0.0                ...
# 739631                                                0.0                ...
# 740480                                                0.0                ...
# 741230                                                0.0                ...
# 741620                                                NaN                ...
#
#         previous_day_admission_pediatric_covid_confirmed_0_4_7_day_sum  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                NaN
# 741230                                                0.0
# 741620                                                NaN
#
#         previous_day_admission_pediatric_covid_confirmed_12_17_7_day_sum  \
# 147552                                                NaN
# 577721                                                NaN
# 70132                                                 NaN
# 571322                                                NaN
# 149854                                                0.0
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                NaN
# 741230                                                0.0
# 741620                                                NaN
#
#         previous_day_admission_pediatric_covid_confirmed_5_11_7_day_sum  \
# 147552                                                NaN
# 577721                                                NaN
# 70132                                                 NaN
# 571322                                                NaN
# 149854                                                0.0
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                NaN
# 741230                                                0.0
# 741620                                                NaN
#
#         previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                NaN
# 741230                                                0.0
# 741620                                                NaN
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                NaN
# 741230                                                0.0
# 741620                                                NaN
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# 147552                                                NaN
# 577721                                                0.0
# 70132                                                 0.0
# 571322                                                NaN
# 149854                                                0.0
# ...                                                   ...
# 739122                                                NaN
# 739631                                                0.0
# 740480                                                NaN
# 741230                                                0.0
# 741620                                                NaN
#
#         staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# 147552                                            NaN
# 577721                                            0.0
# 70132                                             0.0
# 571322                                            NaN
# 149854                                            0.0
# ...                                               ...
# 739122                                            NaN
# 739631                                            0.0
# 740480                                            NaN
# 741230                                            0.0
# 741620                                            NaN
#
#         staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# 147552                                            NaN
# 577721                                            0.0
# 70132                                             0.0
# 571322                                            NaN
# 149854                                            0.0
# ...                                               ...
# 739122                                            NaN
# 739631                                            0.0
# 740480                                            NaN
# 741230                                            0.0
# 741620                                            NaN
#
#         total_staffed_pediatric_icu_beds_7_day_avg  \
# 147552                                         NaN
# 577721                                         0.0
# 70132                                          0.0
# 571322                                         NaN
# 149854                                         0.0
# ...                                            ...
# 739122                                         NaN
# 739631                                         0.0
# 740480                                         NaN
# 741230                                         0.0
# 741620                                         NaN
#
#         total_staffed_pediatric_icu_beds_7_day_sum
# 147552                                         NaN
# 577721                                         0.0
# 70132                                          0.0
# 571322                                         NaN
# 149854                                         0.0
# ...                                            ...
# 739122                                         NaN
# 739631                                         0.0
# 740480                                         NaN
# 741230                                         0.0
# 741620                                         NaN
#
# [742253 rows x 85 columns]

# %%
clean = clean.dropna()
clean = clean.applymap(lambda x: ifZero(x))
clean
# Out:
#         total_beds_7_day_avg  all_adult_hospital_beds_7_day_avg  \
# 520722                  38.3                               38.3
# 723582                  35.0                               35.0
# 527290                  33.6                               33.6
# 381698                  35.0                               35.0
# 283564                  35.0                               35.0
# ...                      ...                                ...
# 161385                 205.9                              196.0
# 504377                  96.5                               96.5
# 653196                  16.0                               16.0
# 716067                 186.0                              186.0
# 601375                  10.0                               10.0
#
#         all_adult_hospital_inpatient_beds_7_day_avg  \
# 520722                                         38.1
# 723582                                         25.0
# 527290                                         25.0
# 381698                                         25.0
# 283564                                         25.0
# ...                                             ...
# 161385                                        202.1
# 504377                                         97.1
# 653196                                         16.0
# 716067                                        169.0
# 601375                                         10.0
#
#         inpatient_beds_used_7_day_avg  \
# 520722                           23.0
# 723582                            9.4
# 527290                           12.0
# 381698                            9.1
# 283564                           16.3
# ...                               ...
# 161385                          205.9
# 504377                           72.4
# 653196                           13.6
# 716067                          147.6
# 601375                            0.0
#
#         all_adult_hospital_inpatient_bed_occupied_7_day_avg  \
# 520722                                               23.0
# 723582                                                9.4
# 527290                                               12.0
# 381698                                                9.1
# 283564                                               16.3
# ...                                                   ...
# 161385                                              202.1
# 504377                                               72.4
# 653196                                               13.6
# 716067                                              147.6
# 601375                                                0.0
#
#         inpatient_beds_used_covid_7_day_avg  \
# 520722                                  9.7
# 723582                                  0.0
# 527290                                  0.0
# 381698                                  0.0
# 283564                                  5.4
# ...                                     ...
# 161385                                 19.3
# 504377                                 17.3
# 653196                                  0.0
# 716067                                 26.9
# 601375                                  0.0
#
#         total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg  \
# 520722                                                9.7
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                5.4
# ...                                                   ...
# 161385                                               17.4
# 504377                                               17.3
# 653196                                                0.0
# 716067                                               26.9
# 601375                                                0.0
#
#         total_adult_patients_hospitalized_confirmed_covid_7_day_avg  \
# 520722                                                9.7
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                4.6
# ...                                                   ...
# 161385                                               11.3
# 504377                                               17.3
# 653196                                                0.0
# 716067                                               25.6
# 601375                                                0.0
#
#         total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                0.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg  ...  \
# 520722                                                0.0                ...
# 723582                                                0.0                ...
# 527290                                                0.0                ...
# 381698                                                0.0                ...
# 283564                                                0.0                ...
# ...                                                   ...                ...
# 161385                                                0.0                ...
# 504377                                                0.0                ...
# 653196                                                0.0                ...
# 716067                                                0.0                ...
# 601375                                                0.0                ...
#
#         previous_day_admission_pediatric_covid_confirmed_0_4_7_day_sum  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                7.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         previous_day_admission_pediatric_covid_confirmed_12_17_7_day_sum  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                0.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         previous_day_admission_pediatric_covid_confirmed_5_11_7_day_sum  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                0.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         previous_day_admission_pediatric_covid_confirmed_unknown_7_day_sum  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                0.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_avg  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                0.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         staffed_icu_pediatric_patients_confirmed_covid_7_day_sum  \
# 520722                                                0.0
# 723582                                                0.0
# 527290                                                0.0
# 381698                                                0.0
# 283564                                                0.0
# ...                                                   ...
# 161385                                                0.0
# 504377                                                0.0
# 653196                                                0.0
# 716067                                                0.0
# 601375                                                0.0
#
#         staffed_pediatric_icu_bed_occupancy_7_day_avg  \
# 520722                                            0.0
# 723582                                            0.0
# 527290                                            0.0
# 381698                                            0.0
# 283564                                            0.0
# ...                                               ...
# 161385                                            0.0
# 504377                                            0.0
# 653196                                            0.0
# 716067                                            0.0
# 601375                                            0.0
#
#         staffed_pediatric_icu_bed_occupancy_7_day_sum  \
# 520722                                            0.0
# 723582                                            0.0
# 527290                                            0.0
# 381698                                            0.0
# 283564                                            0.0
# ...                                               ...
# 161385                                            0.0
# 504377                                            0.0
# 653196                                            0.0
# 716067                                            0.0
# 601375                                            0.0
#
#         total_staffed_pediatric_icu_beds_7_day_avg  \
# 520722                                         0.0
# 723582                                         0.0
# 527290                                         0.0
# 381698                                         0.0
# 283564                                         0.0
# ...                                            ...
# 161385                                         0.0
# 504377                                         0.0
# 653196                                         0.0
# 716067                                         0.0
# 601375                                         0.0
#
#         total_staffed_pediatric_icu_beds_7_day_sum
# 520722                                         0.0
# 723582                                         0.0
# 527290                                         0.0
# 381698                                         0.0
# 283564                                         0.0
# ...                                            ...
# 161385                                         0.0
# 504377                                         0.0
# 653196                                         0.0
# 716067                                         0.0
# 601375                                         0.0
#
# [51537 rows x 85 columns]

# %%
output = clean['inpatient_beds_used_covid_7_day_sum'].values.reshape(-1, 1)
clean = clean.drop('inpatient_beds_used_covid_7_day_sum', axis=1)
'inpatient_beds_used_covid_7_day_sum' in clean
# Out:
# False

# %%
solve = []
maxTrainAccuracy = -1
maxTestAccuracy = -1
index = -1
for col in clean:
  input = clean[col].values.reshape(-1, 1)
  xtrain, xtest, ytrain, ytest = train_test_split(input, output, test_size=0.3, random_state=404)
  dtree = DecisionTreeClassifier(random_state=404)
  dtree.fit(xtrain, ytrain)
  y_pred = dtree.predict(xtest)
  trainAccuracy = accuracy_score(y_true = ytrain, y_pred = dtree.predict(xtrain))
  testAccuracy = accuracy_score(y_true = ytest, y_pred = y_pred)
  
  if testAccuracy > maxTestAccuracy:
    maxTrainAccuracy = trainAccuracy
    maxTestAccuracy = testAccuracy
    index = len(solve)
    
  solve.append({
    'col': col,
    'input': input,
    'output': output,
    'xtrain': xtrain,
    'xtest': xtest,
    'ytrain': ytrain,
    'ytest': ytest,
    'dtree': dtree,
    'y_pred': y_pred,
    'trainAccuracy': trainAccuracy,
    'testAccuracy': testAccuracy,
  })

# %%
print('name:',solve[index].get('col'))
print("index:",index)
print('max training accuracy',maxTrainAccuracy)
print('max test accuracy',maxTestAccuracy)
# Out:
# name: total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum
# index: 25
# max training accuracy 0.8710464310464311
# max test accuracy 0.8624369421808304
